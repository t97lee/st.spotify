# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotliv inline
import pandas as pd 

# %reload_ext autoreload 
# %autoreload 2 #auto reload when the notebook is refreshed

# %%
## Functional plot 
x_1 = np.linspace(0,5,10)
y_1 = x_1**2

plt.plot(x_1,y_1) #shows the plot 
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
plt.show() #use this when youre not using jupyter
# Out:
# Text(0, 0.5, 'Days Squared')

# %%
##printing multiple plots 
plt.subplot(1,2,1)
plt.plot(x_1,y_1, 'k')
plt.subplot(1,2,2)
plt.plot(x_1,y_1, 'b')

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
#bar chart 

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people)) #the black marks 

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
